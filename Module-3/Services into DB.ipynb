# %%
import pandas as pd
from pandas.io import sql
sqlite_db = 'master.sqlite'
conn = sqlite3.connect(sqlite_db) 
c = conn.cursor()

# %%
data = pd.read_csv('./../DATA/services.csv', low_memory = False)
data.head()
# Out:
#   services_on_offer     industry_we_offer cities_we_work  \
# 0      Data Analyst    Financial Products       Brisbane
# 1   Data Consultant  Credit Card Products         Sydney
# 2    Tableau Expert               Banking      Melbourne
# 3     Python Expert        Superannuation            NaN
# 4   Power BI Expert            Home Loans            NaN
#
#                                                 name  \
# 0    Data Analyst for Financial Products in Brisbane
# 1      Data Analyst for Financial Products in Sydney
# 2   Data Analyst for Financial Products in Melbourne
# 3  Data Analyst for Credit Card Products in Brisbane
# 4    Data Analyst for Credit Card Products in Sydney
#
#                                          description       service  \
# 0  Are you looking for a Data Analyst for Financi...  Data Analyst
# 1  Are you looking for a Data Analyst for Financi...  Data Analyst
# 2  Are you looking for a Data Analyst for Financi...  Data Analyst
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.to_sql('services', con = conn, if_exists = 'replace', index = False)

# %%
c.execute('SELECT * FROM services').fetchall()
# Out:
# [('Data Analyst',
#   'Financial Products',
#   'Brisbane',
#   'Data Analyst for Financial Products in Brisbane',
#   'Are you looking for a Data Analyst for Financial Products in Brisbane?',
#   'Data Analyst',
#   'Financial Products',
#   'Brisbane'),
#  ('Data Consultant',
#   'Credit Card Products',
#   'Sydney',
#   'Data Analyst for Financial Products in Sydney',
#   'Are you looking for a Data Analyst for Financial Products in Sydney?',
#   'Data Analyst',
#   'Financial Products',
#   'Sydney'),
#  ('Tableau Expert',
#   'Banking',
#   'Melbourne',
#   'Data Analyst for Financial Products in Melbourne',
#   'Are you looking for a Data Analyst for Financial Products in Melbourne?',
#   'Data Analyst',
#   'Financial Products',
#   'Melbourne'),
#  ('Python Expert',
#   'Superannuation',
#   None,
#   'Data Analyst for Credit Card Products in Brisbane',
#   'Are you looking for a Data Analyst for Credit Card Products in Brisbane?',
#   'Data Analyst',
# ...
